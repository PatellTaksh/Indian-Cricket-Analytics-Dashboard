# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.bcci.tv/international/men/stats/t20i"

# %%
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
table = soup.find_all("table")[1]

rows = table.find_all("tr")

for i, row in enumerate(rows):
    cols = row.find_all("td")

    print(f"\nRow {i} | Total Columns: {len(cols)}")

    for j, col in enumerate(cols):
        h6 = col.find("h6")

        if h6:
            print(f"Column {j}: {h6.text.strip()}")
        else:
            print(f"Column {j}: No <h6> tag")
# Out:
# Row 0 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Virat Kohli
# Column 2: 125
# Column 3: 117
# Column 4: 48.69
# Column 5: 137.04
# Column 6: 122
# Column 7: 369
# Column 8: 124
# Column 9: 38
# Column 10: 1
# Column 11: 4188
#
# Row 1 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Surya Kumar Yadav
# Column 2: 113
# Column 3: 107
# Column 4: 36.35
# Column 5: 162.94
# Column 6: 117
# Column 7: 297
# Column 8: 179
# Column 9: 25
# Column 10: 4
# Column 11: 3272
#
# Row 2 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Hardik Pandya
# Column 2: 138
# Column 3: 109
# Column 4: 28.24
# Column 5: 145.91
# Column 6: 71
# Column 7: 168
# Column 8: 126
# Column 9: 9
# Column 10: -
# Column 11: 2288
#
# Row 3 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: KL Rahul
# Column 2: 72
# Column 3: 68
# Column 4: 37.75
# Column 5: 139.12
# Column 6: 110
# Column 7: 191
# Column 8: 99
# Column 9: 22
# Column 10: 2
# Column 11: 2265
#
# Row 4 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Shikhar Dhawan
# Column 2: 68
# Column 3: 66
# Column 4: 27.92
# Column 5: 126.36
# Column 6: 92
# Column 7: 191
# Column 8: 50
# Column 9: 11
# Column 10: -
# Column 11: 1759
#
# Row 5 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: MS Dhoni
# Column 2: 98
# Column 3: 85
# Column 4: 37.60
# Column 5: 126.13
# Column 6: 56
# Column 7: 116
# Column 8: 52
# Column 9: 2
# Column 10: -
# Column 11: 1617
#
# Row 6 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Suresh Raina
# Column 2: 78
# Column 3: 66
# Column 4: 29.18
# Column 5: 134.87
# Column 6: 101
# Column 7: 145
# Column 8: 58
# Column 9: 5
# Column 10: 1
# Column 11: 1605
#
# Row 7 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Abhishek Sharma
# Column 2: 50
# Column 3: 49
# Column 4: 33.80
# Column 5: 192.83
# Column 6: 135
# Column 7: 160
# Column 8: 103
# Column 9: 11
# Column 10: 2
# Column 11: 1589
#
# Row 8 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: N. Tilak Varma
# Column 2: 53
# Column 3: 50
# Column 4: 44.14
# Column 5: 143.49
# Column 6: 120
# Column 7: 117
# Column 8: 75
# Column 9: 7
# Column 10: 2
# Column 11: 1501
#
# Row 9 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Sanju Samson
# Column 2: 65
# Column 3: 57
# Column 4: 27.01
# Column 5: 155.42
# Column 6: 111
# Column 7: 116
# Column 8: 84
# Column 9: 6
# Column 10: 3
# Column 11: 1405
#
# Row 10 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ishan Kishan
# Column 2: 48
# Column 3: 48
# Column 4: 28.53
# Column 5: 146.55
# Column 6: 103
# Column 7: 135
# Column 8: 70
# Column 9: 10
# Column 10: 1
# Column 11: 1341
#
# Row 11 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Rishabh Pant
# Column 2: 76
# Column 3: 66
# Column 4: 23.25
# Column 5: 127.26
# Column 6: 65
# Column 7: 111
# Column 8: 44
# Column 9: 3
# Column 10: -
# Column 11: 1209
#
# Row 12 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Shreyas Iyer
# Column 2: 54
# Column 3: 50
# Column 4: 30.38
# Column 5: 135.89
# Column 6: 74
# Column 7: 98
# Column 8: 45
# Column 9: 9
# Column 10: -
# Column 11: 1185
#
# Row 13 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Yuvraj Singh
# Column 2: 58
# Column 3: 51
# Column 4: 28.02
# Column 5: 136.38
# Column 6: 77
# Column 7: 77
# Column 8: 74
# Column 9: 8
# Column 10: -
# Column 11: 1177
#
# Row 14 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Shivam Dube
# Column 2: 67
# Column 3: 51
# Column 4: 31.70
# Column 5: 155.33
# Column 6: 66
# Column 7: 69
# Column 8: 68
# Column 9: 6
# Column 10: -
# Column 11: 1078
#
# Row 15 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Gautam Gambhir
# Column 2: 37
# Column 3: 36
# Column 4: 27.41
# Column 5: 119.02
# Column 6: 75
# Column 7: 109
# Column 8: 10
# Column 9: 7
# Column 10: -
# Column 11: 932
#
# Row 16 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Shubman Gill
# Column 2: 36
# Column 3: 36
# Column 4: 28.03
# Column 5: 138.59
# Column 6: 126
# Column 7: 98
# Column 8: 26
# Column 9: 3
# Column 10: 1
# Column 11: 869
#
# Row 17 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Axar Patel
# Column 2: 96
# Column 3: 59
# Column 4: 18.27
# Column 5: 131
# Column 6: 65
# Column 7: 51
# Column 8: 28
# Column 9: 1
# Column 10: -
# Column 11: 731
#
# Row 18 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Yashasvi Jaiswal
# Column 2: 23
# Column 3: 22
# Column 4: 36.15
# Column 5: 164.31
# Column 6: 100
# Column 7: 82
# Column 8: 38
# Column 9: 5
# Column 10: 1
# Column 11: 723
#
# Row 19 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Manish Pandey
# Column 2: 39
# Column 3: 33
# Column 4: 44.31
# Column 5: 126.15
# Column 6: 79
# Column 7: 49
# Column 8: 19
# Column 9: 3
# Column 10: -
# Column 11: 709
#
# Row 20 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Dinesh Karthik
# Column 2: 60
# Column 3: 48
# Column 4: 26.38
# Column 5: 142.61
# Column 6: 55
# Column 7: 71
# Column 8: 28
# Column 9: 1
# Column 10: -
# Column 11: 686
#
# Row 21 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Rinku Singh
# Column 2: 45
# Column 3: 33
# Column 4: 39.11
# Column 5: 155.73
# Column 6: 69
# Column 7: 55
# Column 8: 38
# Column 9: 3
# Column 10: -
# Column 11: 665
#
# Row 22 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ruturaj Gaikwad
# Column 2: 23
# Column 3: 20
# Column 4: 39.56
# Column 5: 143.53
# Column 6: 123
# Column 7: 65
# Column 8: 24
# Column 9: 4
# Column 10: 1
# Column 11: 633
#
# Row 23 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ravindra Jadeja
# Column 2: 74
# Column 3: 41
# Column 4: 21.45
# Column 5: 127.16
# Column 6: 46
# Column 7: 39
# Column 8: 14
# Column 9: -
# Column 10: -
# Column 11: 515
#
# Row 24 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Virender Sehwag
# Column 2: 19
# Column 3: 18
# Column 4: 21.88
# Column 5: 145.38
# Column 6: 68
# Column 7: 43
# Column 8: 16
# Column 9: 2
# Column 10: -
# Column 11: 394
#
# Row 25 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ajinkya Rahane
# Column 2: 20
# Column 3: 20
# Column 4: 20.83
# Column 5: 113.29
# Column 6: 61
# Column 7: 32
# Column 8: 6
# Column 9: 1
# Column 10: -
# Column 11: 375
#
# Row 26 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Deepak Hooda
# Column 2: 21
# Column 3: 17
# Column 4: 30.66
# Column 5: 147.2
# Column 6: 104
# Column 7: 29
# Column 8: 18
# Column 9: -
# Column 10: 1
# Column 11: 368
#
# Row 27 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Washington Sundar
# Column 2: 61
# Column 3: 26
# Column 4: 16.11
# Column 5: 129.24
# Column 6: 50
# Column 7: 21
# Column 8: 14
# Column 9: 1
# Column 10: -
# Column 11: 274
#
# Row 28 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Robin Uthappa
# Column 2: 13
# Column 3: 12
# Column 4: 24.90
# Column 5: 118
# Column 6: 50
# Column 7: 26
# Column 8: 6
# Column 9: 1
# Column 10: -
# Column 11: 249
#
# Row 29 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Yusuf Pathan
# Column 2: 22
# Column 3: 18
# Column 4: 18.15
# Column 5: 146.58
# Column 6: 37
# Column 7: 11
# Column 8: 17
# Column 9: -
# Column 10: -
# Column 11: 236
#
# Row 30 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ravichandran Ashwin
# Column 2: 65
# Column 3: 19
# Column 4: 26.28
# Column 5: 114.99
# Column 6: 31
# Column 7: 17
# Column 8: 4
# Column 9: -
# Column 10: -
# Column 11: 184
#
# Row 31 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Irfan Pathan
# Column 2: 24
# Column 3: 14
# Column 4: 24.57
# Column 5: 119.44
# Column 6: 33
# Column 7: 9
# Column 8: 7
# Column 9: -
# Column 10: -
# Column 11: 172
#
# Row 32 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Murali Vijay
# Column 2: 9
# Column 3: 9
# Column 4: 18.77
# Column 5: 109.74
# Column 6: 48
# Column 7: 13
# Column 8: 8
# Column 9: -
# Column 10: -
# Column 11: 169
#
# Row 33 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Venkatesh Iyer
# Column 2: 9
# Column 3: 7
# Column 4: 33.25
# Column 5: 162.19
# Column 6: 35
# Column 7: 15
# Column 8: 5
# Column 9: -
# Column 10: -
# Column 11: 133
#
# Row 34 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Krunal Pandya
# Column 2: 19
# Column 3: 10
# Column 4: 24.80
# Column 5: 130.52
# Column 6: 26
# Column 7: 8
# Column 8: 6
# Column 9: -
# Column 10: -
# Column 11: 124
#
# Row 35 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Kedar Jadhav
# Column 2: 9
# Column 3: 6
# Column 4: 20.33
# Column 5: 123.23
# Column 6: 58
# Column 7: 12
# Column 8: 3
# Column 9: 1
# Column 10: -
# Column 11: 122
#
# Row 36 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Harbhajan Singh
# Column 2: 28
# Column 3: 13
# Column 4: 13.50
# Column 5: 124.13
# Column 6: 21
# Column 7: 11
# Column 8: 4
# Column 9: -
# Column 10: -
# Column 11: 108
#
# Row 37 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Vijay Shankar
# Column 2: 9
# Column 3: 4
# Column 4: 25.25
# Column 5: 138.35
# Column 6: 43
# Column 7: 11
# Column 8: 5
# Column 9: -
# Column 10: -
# Column 11: 101
#
# Row 38 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Rahul Tripathi
# Column 2: 5
# Column 3: 5
# Column 4: 19.40
# Column 5: 144.77
# Column 6: 44
# Column 7: 11
# Column 8: 5
# Column 9: -
# Column 10: -
# Column 11: 97
#
# Row 39 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Arshdeep Singh
# Column 2: 87
# Column 3: 31
# Column 4: 5.93
# Column 5: 100
# Column 6: 12
# Column 7: 9
# Column 8: 3
# Column 9: -
# Column 10: -
# Column 11: 95
#
# Row 40 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Nitish Kumar Reddy
# Column 2: 4
# Column 3: 3
# Column 4: 45.00
# Column 5: 180
# Column 6: 74
# Column 7: 4
# Column 8: 8
# Column 9: 1
# Column 10: -
# Column 11: 90
#
# Row 41 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Mandeep Singh
# Column 2: 3
# Column 3: 3
# Column 4: 43.50
# Column 5: 119.17
# Column 6: 52
# Column 7: 11
# Column 8: 1
# Column 9: 1
# Column 10: -
# Column 11: 87
#
# Row 42 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Harshit Rana
# Column 2: 12
# Column 3: 6
# Column 4: 17.20
# Column 5: 114.66
# Column 6: 35
# Column 7: 6
# Column 8: 4
# Column 9: -
# Column 10: -
# Column 11: 86
#
# Row 43 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Harshal Patel
# Column 2: 25
# Column 3: 10
# Column 4: 12.83
# Column 5: 135.08
# Column 6: 18
# Column 7: 9
# Column 8: 3
# Column 9: -
# Column 10: -
# Column 11: 77
#
# Row 44 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Shardul Thakur
# Column 2: 25
# Column 3: 6
# Column 4: 23.00
# Column 5: 181.57
# Column 6: 22
# Column 7: 5
# Column 8: 4
# Column 9: -
# Column 10: -
# Column 11: 69
#
# Row 45 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Bhuvneshwar Kumar
# Column 2: 87
# Column 3: 21
# Column 4: 8.37
# Column 5: 71.27
# Column 6: 16
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 67
#
# Row 46 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ravi Bishnoi
# Column 2: 46
# Column 3: 14
# Column 4: 9.28
# Column 5: 125
# Column 6: 10
# Column 7: 9
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 65
#
# Row 47 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Deepak Chahar
# Column 2: 25
# Column 3: 7
# Column 4: 26.50
# Column 5: 189.28
# Column 6: 31
# Column 7: 4
# Column 8: 4
# Column 9: -
# Column 10: -
# Column 11: 53
#
# Row 48 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Kuldeep Yadav
# Column 2: 54
# Column 3: 10
# Column 4: 8.00
# Column 5: 67.6
# Column 6: 23
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 48
#
# Row 49 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: S Badrinath
# Column 2: 1
# Column 3: 1
# Column 4: 43.00
# Column 5: 116.21
# Column 6: 43
# Column 7: 5
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 43
#
# Row 50 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ambati Rayudu
# Column 2: 6
# Column 3: 5
# Column 4: 10.50
# Column 5: 84
# Column 6: 20
# Column 7: 5
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 42
#
# Row 51 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Devdutt Padikkal
# Column 2: 2
# Column 3: 2
# Column 4: 19.00
# Column 5: 100
# Column 6: 29
# Column 7: 2
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 38
#
# Row 52 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Dinesh Mongia
# Column 2: 1
# Column 3: 1
# Column 4: 38.00
# Column 5: 84.44
# Column 6: 38
# Column 7: 4
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 38
#
# Row 53 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Parthiv Patel
# Column 2: 2
# Column 3: 2
# Column 4: 18.00
# Column 5: 112.50
# Column 6: 26
# Column 7: 4
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 36
#
# Row 54 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Stuart Binny
# Column 2: 3
# Column 3: 2
# Column 4: 17.50
# Column 5: 120.68
# Column 6: 24
# Column 7: 2
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 35
#
# Row 55 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Rahul Dravid
# Column 2: 1
# Column 3: 1
# Column 4: 31.00
# Column 5: 147.61
# Column 6: 31
# Column 7: -
# Column 8: 3
# Column 9: -
# Column 10: -
# Column 11: 31
#
# Row 56 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ashish Nehra
# Column 2: 27
# Column 3: 5
# Column 4: 5.60
# Column 5: 71.79
# Column 6: 22
# Column 7: 1
# Column 8: 2
# Column 9: -
# Column 10: -
# Column 11: 28
#
# Row 57 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Shivam Mavi
# Column 2: 6
# Column 3: 2
# Column 4: 14.00
# Column 5: 155.55
# Column 6: 26
# Column 7: 2
# Column 8: 2
# Column 9: -
# Column 10: -
# Column 11: 28
#
# Row 58 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Avesh Khan
# Column 2: 25
# Column 3: 5
# Column 4: 13.50
# Column 5: 135
# Column 6: 16
# Column 7: 3
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 27
#
# Row 59 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ashok Dinda
# Column 2: 9
# Column 3: 2
# Column 4: 22.00
# Column 5: 91.66
# Column 6: 19
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 22
#
# Row 60 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Umesh Yadav
# Column 2: 9
# Column 3: 2
# Column 4: 22.00
# Column 5: 104.76
# Column 6: 20
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 22
#
# Row 61 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Sreesanth
# Column 2: 10
# Column 3: 3
# Column 4: 20.00
# Column 5: 142.85
# Column 6: 19
# Column 7: 4
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 20
#
# Row 62 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ajit Agarkar
# Column 2: 4
# Column 3: 2
# Column 4: 7.50
# Column 5: 136.36
# Column 6: 14
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 15
#
# Row 63 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Manoj Tiwary
# Column 2: 3
# Column 3: 1
# Column 4: 15.00
# Column 5: 88.23
# Column 6: 15
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 15
#
# Row 64 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Nitish Rana
# Column 2: 2
# Column 3: 2
# Column 4: 7.50
# Column 5: 55.55
# Column 6: 9
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 15
#
# Row 65 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ramandeep Singh
# Column 2: 2
# Column 3: 1
# Column 4: 15.00
# Column 5: 250
# Column 6: 15
# Column 7: 1
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 15
#
# Row 66 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Mohammed Siraj
# Column 2: 17
# Column 3: 4
# Column 4: 7.00
# Column 5: 87.5
# Column 6: 7
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 14
#
# Row 67 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Vaibhav Sooryavanshi
# Column 2: 1
# Column 3: 1
# Column 4: 14.00
# Column 5: 140
# Column 6: 14
# Column 7: -
# Column 8: 2
# Column 9: -
# Column 10: -
# Column 11: 14
#
# Row 68 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Zaheer Khan
# Column 2: 17
# Column 3: 4
# Column 4: 6.50
# Column 5: 130.00
# Column 6: 9
# Column 7: -
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 13
#
# Row 69 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Jasprit Bumrah
# Column 2: 95
# Column 3: 12
# Column 4: 2.00
# Column 5: 66.66
# Column 6: 7
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 12
#
# Row 70 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Navdeep Saini
# Column 2: 11
# Column 3: 3
# Column 4: 0.00
# Column 5: 109.09
# Column 6: 11
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 12
#
# Row 71 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Dhruv Jurel
# Column 2: 4
# Column 3: 3
# Column 4: 4.00
# Column 5: 52.17
# Column 6: 6
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 12
#
# Row 72 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Naman Ojha
# Column 2: 2
# Column 3: 2
# Column 4: 6.00
# Column 5: 44.44
# Column 6: 10
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 12
#
# Row 73 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Pragyan Ojha
# Column 2: 6
# Column 3: 1
# Column 4: 0.00
# Column 5: 166.66
# Column 6: 10
# Column 7: -
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 10
#
# Row 74 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Sachin Tendulkar
# Column 2: 1
# Column 3: 1
# Column 4: 10.00
# Column 5: 83.33
# Column 6: 10
# Column 7: 2
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 10
#
# Row 75 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Ishant Sharma
# Column 2: 14
# Column 3: 3
# Column 4: 8.00
# Column 5: 88.88
# Column 6: 5
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 8
#
# Row 76 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Praveen Kumar
# Column 2: 10
# Column 3: 3
# Column 4: 2.33
# Column 5: 43.75
# Column 6: 6
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 7
#
# Row 77 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Yuzvendra Chahal
# Column 2: 80
# Column 3: 6
# Column 4: 3.00
# Column 5: 46.15
# Column 6: 3
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 6
#
# Row 78 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Mohammad Shami
# Column 2: 25
# Column 3: 5
# Column 4: 3.00
# Column 5: 60
# Column 6: 6
# Column 7: -
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 6
#
# Row 79 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Prince Yadav
# Column 2: 1
# Column 3: 1
# Column 4: 0.00
# Column 5: 600
# Column 6: 6
# Column 7: -
# Column 8: 1
# Column 9: -
# Column 10: -
# Column 11: 6
#
# Row 80 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Mukesh Kumar
# Column 2: 17
# Column 3: 4
# Column 4: 5.00
# Column 5: 100
# Column 6: 4
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 5
#
# Row 81 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Umran Malik
# Column 2: 8
# Column 3: 2
# Column 4: 0.00
# Column 5: 250
# Column 6: 4
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 5
#
# Row 82 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Rahul Chahar
# Column 2: 6
# Column 3: 1
# Column 4: 5.00
# Column 5: 100
# Column 6: 5
# Column 7: 1
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 5
#
# Row 83 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Chetan Sakariya
# Column 2: 2
# Column 3: 1
# Column 4: 0.00
# Column 5: 55.55
# Column 6: 5
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 5
#
# Row 84 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Parvez Rasool
# Column 2: 1
# Column 3: 1
# Column 4: 5.00
# Column 5: 83.33
# Column 6: 5
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 5
#
# Row 85 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Varun Chakaravarthy
# Column 2: 46
# Column 3: 10
# Column 4: 0.75
# Column 5: 20
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 3
#
# Row 86 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: RP Singh
# Column 2: 10
# Column 3: 2
# Column 4: 0.00
# Column 5: 100.00
# Column 6: 2
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 3
#
# Row 87 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Mohit Sharma
# Column 2: 8
# Column 3: 2
# Column 4: 0.00
# Column 5: 42.85
# Column 6: 3
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 3
#
# Row 88 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Vinay Kumar
# Column 2: 9
# Column 3: 1
# Column 4: 0.00
# Column 5: 50
# Column 6: 2
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 2
#
# Row 89 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Syed Khaleel Ahmed
# Column 2: 18
# Column 3: 2
# Column 4: 0.00
# Column 5: 50
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 1
#
# Row 90 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Prasidh Krishna
# Column 2: 6
# Column 3: 1
# Column 4: 0.00
# Column 5: 50
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 1
#
# Row 91 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Sandeep Sharma
# Column 2: 2
# Column 3: 1
# Column 4: 0.00
# Column 5: 100
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 1
#
# Row 92 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Dhawal Kulkarni
# Column 2: 2
# Column 3: 1
# Column 4: 0.00
# Column 5: 100.00
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 1
#
# Row 93 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Suryansh Shedge
# Column 2: 1
# Column 3: 1
# Column 4: 1.00
# Column 5: 20
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 1
#
# Row 94 | Total Columns: 12
# Column 0: No <h6> tag
# Column 1: Rishi Dhawan
# Column 2: 1
# Column 3: 1
# Column 4: 0.00
# Column 5: 50
# Column 6: 1
# Column 7: -
# Column 8: -
# Column 9: -
# Column 10: -
# Column 11: 1

# %%
table = soup.find_all("table")[1]
rows = table.find_all("tr")

data = []

for row in rows:

    cols = row.find_all("td")

    rank = cols[0].find("h5").text.strip()
    player = cols[1].find("h6").text.strip()
    matches = cols[2].find("h6").text.strip()
    innings = cols[3].find("h6").text.strip()
    average = cols[4].find("h6").text.strip()
    strike_rate = cols[5].find("h6").text.strip()
    highest_score = cols[6].find("h6").text.strip()
    fours = cols[7].find("h6").text.strip()
    sixes = cols[8].find("h6").text.strip()
    fifties = cols[9].find("h6").text.strip()
    hundreds = cols[10].find("h6").text.strip()
    runs = cols[11].find("h6").text.strip()

    print(rank, player, matches, innings, average, strike_rate, highest_score, fours, sixes, fifties, hundreds, runs)

    data.append([
    rank,
    player,
    matches,
    innings,
    average,
    strike_rate,
    highest_score,
    fours,
    sixes,
    fifties,
    hundreds,
    runs
])
# Out:
# 2 Virat Kohli 125 117 48.69 137.04 122 369 124 38 1 4188
# 3 Surya Kumar Yadav 113 107 36.35 162.94 117 297 179 25 4 3272
# 4 Hardik Pandya 138 109 28.24 145.91 71 168 126 9 - 2288
# 5 KL Rahul 72 68 37.75 139.12 110 191 99 22 2 2265
# 6 Shikhar Dhawan 68 66 27.92 126.36 92 191 50 11 - 1759
# 7 MS Dhoni 98 85 37.60 126.13 56 116 52 2 - 1617
# 8 Suresh Raina 78 66 29.18 134.87 101 145 58 5 1 1605
# 9 Abhishek Sharma 50 49 33.80 192.83 135 160 103 11 2 1589
# 10 N. Tilak Varma 53 50 44.14 143.49 120 117 75 7 2 1501
# 11 Sanju Samson 65 57 27.01 155.42 111 116 84 6 3 1405
# 12 Ishan Kishan 48 48 28.53 146.55 103 135 70 10 1 1341
# 13 Rishabh Pant 76 66 23.25 127.26 65 111 44 3 - 1209
# 14 Shreyas Iyer 54 50 30.38 135.89 74 98 45 9 - 1185
# 15 Yuvraj Singh 58 51 28.02 136.38 77 77 74 8 - 1177
# 16 Shivam Dube 67 51 31.70 155.33 66 69 68 6 - 1078
# 17 Gautam Gambhir 37 36 27.41 119.02 75 109 10 7 - 932
# 18 Shubman Gill 36 36 28.03 138.59 126 98 26 3 1 869
# 19 Axar Patel 96 59 18.27 131 65 51 28 1 - 731
# 20 Yashasvi Jaiswal 23 22 36.15 164.31 100 82 38 5 1 723
# 21 Manish Pandey 39 33 44.31 126.15 79 49 19 3 - 709
# 22 Dinesh Karthik 60 48 26.38 142.61 55 71 28 1 - 686
# 23 Rinku Singh 45 33 39.11 155.73 69 55 38 3 - 665
# 24 Ruturaj Gaikwad 23 20 39.56 143.53 123 65 24 4 1 633
# 25 Ravindra Jadeja 74 41 21.45 127.16 46 39 14 - - 515
# 26 Virender Sehwag 19 18 21.88 145.38 68 43 16 2 - 394
# 27 Ajinkya Rahane 20 20 20.83 113.29 61 32 6 1 - 375
# 28 Deepak Hooda 21 17 30.66 147.2 104 29 18 - 1 368
# 29 Washington Sundar 61 26 16.11 129.24 50 21 14 1 - 274
# 30 Robin Uthappa 13 12 24.90 118 50 26 6 1 - 249
# 31 Yusuf Pathan 22 18 18.15 146.58 37 11 17 - - 236
# 32 Ravichandran Ashwin 65 19 26.28 114.99 31 17 4 - - 184
# 33 Irfan Pathan 24 14 24.57 119.44 33 9 7 - - 172
# 34 Murali Vijay 9 9 18.77 109.74 48 13 8 - - 169
# 35 Venkatesh Iyer 9 7 33.25 162.19 35 15 5 - - 133
# 36 Krunal Pandya 19 10 24.80 130.52 26 8 6 - - 124
# 37 Kedar Jadhav 9 6 20.33 123.23 58 12 3 1 - 122
# 38 Harbhajan Singh 28 13 13.50 124.13 21 11 4 - - 108
# 39 Vijay Shankar 9 4 25.25 138.35 43 11 5 - - 101
# 40 Rahul Tripathi 5 5 19.40 144.77 44 11 5 - - 97
# 41 Arshdeep Singh 87 31 5.93 100 12 9 3 - - 95
# 42 Nitish Kumar Reddy 4 3 45.00 180 74 4 8 1 - 90
# 43 Mandeep Singh 3 3 43.50 119.17 52 11 1 1 - 87
# 44 Harshit Rana 12 6 17.20 114.66 35 6 4 - - 86
# 45 Harshal Patel 25 10 12.83 135.08 18 9 3 - - 77
# 46 Shardul Thakur 25 6 23.00 181.57 22 5 4 - - 69
# 47 Bhuvneshwar Kumar 87 21 8.37 71.27 16 - - - - 67
# 48 Ravi Bishnoi 46 14 9.28 125 10 9 1 - - 65
# 49 Deepak Chahar 25 7 26.50 189.28 31 4 4 - - 53
# 50 Kuldeep Yadav 54 10 8.00 67.6 23 2 - - - 48
# 51 S Badrinath 1 1 43.00 116.21 43 5 - - - 43
# 52 Ambati Rayudu 6 5 10.50 84 20 5 - - - 42
# 53 Devdutt Padikkal 2 2 19.00 100 29 2 1 - - 38
# 54 Dinesh Mongia 1 1 38.00 84.44 38 4 1 - - 38
# 55 Parthiv Patel 2 2 18.00 112.50 26 4 1 - - 36
# 56 Stuart Binny 3 2 17.50 120.68 24 2 1 - - 35
# 57 Rahul Dravid 1 1 31.00 147.61 31 - 3 - - 31
# 58 Ashish Nehra 27 5 5.60 71.79 22 1 2 - - 28
# 59 Shivam Mavi 6 2 14.00 155.55 26 2 2 - - 28
# 60 Avesh Khan 25 5 13.50 135 16 3 1 - - 27
# 61 Ashok Dinda 9 2 22.00 91.66 19 1 - - - 22
# 62 Umesh Yadav 9 2 22.00 104.76 20 2 - - - 22
# 63 Sreesanth 10 3 20.00 142.85 19 4 - - - 20
# 64 Ajit Agarkar 4 2 7.50 136.36 14 2 - - - 15
# 65 Manoj Tiwary 3 1 15.00 88.23 15 - - - - 15
# 66 Nitish Rana 2 2 7.50 55.55 9 - - - - 15
# 67 Ramandeep Singh 2 1 15.00 250 15 1 1 - - 15
# 68 Mohammed Siraj 17 4 7.00 87.5 7 1 - - - 14
# 69 Vaibhav Sooryavanshi 1 1 14.00 140 14 - 2 - - 14
# 70 Zaheer Khan 17 4 6.50 130.00 9 - 1 - - 13
# 71 Jasprit Bumrah 95 12 2.00 66.66 7 2 - - - 12
# 72 Navdeep Saini 11 3 0.00 109.09 11 2 - - - 12
# 73 Dhruv Jurel 4 3 4.00 52.17 6 1 - - - 12
# 74 Naman Ojha 2 2 6.00 44.44 10 2 - - - 12
# 75 Pragyan Ojha 6 1 0.00 166.66 10 - 1 - - 10
# 76 Sachin Tendulkar 1 1 10.00 83.33 10 2 - - - 10
# 77 Ishant Sharma 14 3 8.00 88.88 5 1 - - - 8
# 78 Praveen Kumar 10 3 2.33 43.75 6 - - - - 7
# 79 Yuzvendra Chahal 80 6 3.00 46.15 3 - - - - 6
# 80 Mohammad Shami 25 5 3.00 60 6 - 1 - - 6
# 81 Prince Yadav 1 1 0.00 600 6 - 1 - - 6
# 82 Mukesh Kumar 17 4 5.00 100 4 1 - - - 5
# 83 Umran Malik 8 2 0.00 250 4 1 - - - 5
# 84 Rahul Chahar 6 1 5.00 100 5 1 - - - 5
# 85 Chetan Sakariya 2 1 0.00 55.55 5 - - - - 5
# 86 Parvez Rasool 1 1 5.00 83.33 5 - - - - 5
# 87 Varun Chakaravarthy 46 10 0.75 20 1 - - - - 3
# 88 RP Singh 10 2 0.00 100.00 2 - - - - 3
# 89 Mohit Sharma 8 2 0.00 42.85 3 - - - - 3
# 90 Vinay Kumar 9 1 0.00 50 2 - - - - 2
# 91 Syed Khaleel Ahmed 18 2 0.00 50 1 - - - - 1
# 92 Prasidh Krishna 6 1 0.00 50 1 - - - - 1
# 93 Sandeep Sharma 2 1 0.00 100 1 - - - - 1
# 94 Dhawal Kulkarni 2 1 0.00 100.00 1 - - - - 1
# 95 Suryansh Shedge 1 1 1.00 20 1 - - - - 1
# 96 Rishi Dhawan 1 1 0.00 50 1 - - - - 1

# %%
table0 = soup.find_all("table")[0]
cols = table0.find_all("td")

# %%
stats = {}

for td in cols:
    key = td.find("span").text.strip()
    value = td.find("p").text.strip()
    stats[key] = value

# %%
matches = stats["Matches"]
innings = stats["Inns"]
average = stats["Avg."]
strike_rate = stats["SR"]
highest_score = stats["HS"]
fours = stats["4’s"]
sixes = stats["6’s"]
fifties = stats["50’s"]
hundreds = stats["100’s"]
runs = stats["Runs"]

# %%
top_player = soup.find("div", class_="team-ranking-wrapper player")
rank = top_player.find("h1").text.strip().replace("#", "")

# %%
name_div = top_player.find("div", class_="player-name-trw text-white mb-3")
player = " ".join(name_div.stripped_strings)

# %%
data.insert(0, [
    rank,
    player,
    matches,
    innings,
    average,
    strike_rate,
    highest_score,
    fours,
    sixes,
    fifties,
    hundreds,
    runs
])

print(rank)
print(player)
print(matches)
print(innings)
print(average)
print(strike_rate)
print(highest_score)
print(fours)
print(sixes)
print(fifties)
print(hundreds)
print(runs)
# Out:
# 1
# Rohit Sharma
# 159
# 151
# 32.05
# 140.89
# 121
# 383
# 205
# 32
# 5
# 4231

# %%
df = pd.DataFrame(data, columns=[
    "Rank",
    "Player",
    "Matches",
    "Innings",
    "Average",
    "Strike Rate",
    "Highest Score",
    "Fours",
    "Sixes",
    "Fifties",
    "Hundreds",
    "Runs"
])

# %%
df.head()
# Out:
#   Rank             Player Matches Innings Average Strike Rate Highest Score  \
# 0    1       Rohit Sharma     159     151   32.05      140.89           121
# 1    2        Virat Kohli     125     117   48.69      137.04           122
# 2    3  Surya Kumar Yadav     113     107   36.35      162.94           117
# 3    4      Hardik Pandya     138     109   28.24      145.91            71
# 4    5           KL Rahul      72      68   37.75      139.12           110
#
#   Fours Sixes Fifties Hundreds  Runs
# 0   383   205      32        5  4231
# 1   369   124      38        1  4188
# 2   297   179      25        4  3272
# 3   168   126       9        -  2288
# 4   191    99      22        2  2265

# %%
df.to_csv("Scraped_Data/Men_T20i_Analysis.csv", index=False, encoding="utf-8")
